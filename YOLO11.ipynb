# %% [markdown]
# <a href="https://colab.research.google.com/github/Ktpyy16/dara-science-bootcamp-8/blob/main/YOLO11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup YOLO11
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.26 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.6/112.6 GB disk)

# %% [markdown]
# # 1. Predict ( Test Setup YOLO11)
#
# YOLOv11s may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLO11 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLOv11s
# !yolo predict model=yolo11s.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# ...
# Ultralytics 8.4.26 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 100 layers, 9,443,760 parameters, 0 gradients, 21.5 GFLOPs
#
# ...
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 2 ties, 53.1ms
# Speed: 11.1ms preprocess, 53.1ms inference, 42.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 2. Add Zip Data Export YOLO11 for Roboflow

# %%
import zipfile
from google.colab import files

# %cd /content
uploaded = files.upload()
for filename in uploaded.keys():
  pass

zip_ref = zipfile.ZipFile(filename, 'r')
zip_ref.extractall("/content/")
# Out:
# /content
#      <input type="file" id="files-0951c8ac-149a-4a8d-aaf5-dec5bfee8aee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0951c8ac-149a-4a8d-aaf5-dec5bfee8aee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# # 3. Train Data Roboflow

# %%
# Validate YOLOv11s
# !yolo train model=yolo11s.pt data=data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.4.26 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# # 4. Test Model Training

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt conf=0.8 imgsz=640 source='/content/test/images/'
# Out:
# Ultralytics 8.4.26 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,413,961 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/3 /content/test/images/Dataset_mp4-0004_jpg.rf.8b2552bb89bc0992424c01d330549237.jpg: 640x384 2 1s, 59.0ms
# image 2/3 /content/test/images/Dataset_mp4-0009_jpg.rf.92aba14d670157acf449ca00bdb5e17d.jpg: 640x384 2 1s, 1 10, 2 5s, 10.1ms
# image 3/3 /content/test/images/Dataset_mp4-0032_jpg.rf.53c2fe95e024064deda57a5dd92c406b.jpg: 640x384 1 1, 10.1ms
# Speed: 2.3ms preprocess, 26.4ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to /content/runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 5. Test Video for Model Ai

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt  conf=0.8 imgsz=640 source='/content/drive/MyDrive/1A/DataTestENV2.mp4'
